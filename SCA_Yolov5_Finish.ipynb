# %% [markdown]
# # Step 1: Install Requirements

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15291, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 15291 (delta 0), reused 1 (delta 0), pack-reused 15287
# Receiving objects: 100% (15291/15291), 14.19 MiB | 22.64 MiB/s, done.
# Resolving deltas: 100% (10483/10483), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 3.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.5.1 which is incompatible.
# ...

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Mar  8 07:28:58 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    10W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/wadidaw/Model/Model_yolov5l6_640_32_3200/best.pt --img 616 --conf 0.1 --source /content/drive/MyDrive/wadidaw/Done_test_SK2_SK3
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/Done_test_SK2_SK3, data=data/coco128.yaml, imgsz=[616, 616], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-117-g85f6019 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "detect.py", line 261, in <module>
#     main(opt)
#   File "detect.py", line 256, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 98, in run
# ...

# %%
from skimage import data, io
import matplotlib.pyplot as plt 
name = 'IMG_1995.JPG'
Ori=io.imread('/content/Untitled_Folder/IMG_1995.JPG') 
Result =io.imread('/content/yolov5/runs/detect/exp4/IMG_1995.JPG') 
print(' ')
print("\033[1;30;43mData ID : ",name)
print('-----------------------')
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1), plt.title(name), plt.imshow(Ori), plt.axis('off')
plt.subplot(1, 2, 2), plt.title('Prediction'),plt.imshow(Result), plt.axis('off')
# Out:
#
# Data ID :  IMG_1995.JPG
# -----------------------
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fb4979b4450>,
#  Text(0.5, 1.0, 'Prediction'),
# ...
#  (-0.5, 3071.5, 2303.5, -0.5))

# %% [markdown]
# # Negatif

# %%
#25012301A-356
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/negatif/25012301A-356
# Out:
# python3: can't open file 'detect.py': [Errno 2] No such file or directory

# %%
#25012301B-356
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/negatif/25012301B-356
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/negatif/25012301B-356, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/300 /content/drive/MyDrive/wadidaw/negatif/25012301B-356/IMG_5611.JPG: 512x640 32 AFBs, 50.8ms
# image 2/300 /content/drive/MyDrive/wadidaw/negatif/25012301B-356/IMG_5612.JPG: 512x640 (no detections), 50.5ms
# ...

# %%
#25012301A-356
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/negatif/25012301A-356
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/negatif/25012301A-356, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/300 /content/drive/MyDrive/wadidaw/negatif/25012301A-356/IMG_5969.JPG: 512x640 (no detections), 50.8ms
# image 2/300 /content/drive/MyDrive/wadidaw/negatif/25012301A-356/IMG_5970.JPG: 512x640 12 AFBs, 46.5ms
# ...

# %%
#25018301B-381
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/negatif/25018301B-381
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/negatif/25018301B-381, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/303 /content/drive/MyDrive/wadidaw/negatif/25018301B-381/IMG_6008.JPG: 512x640 (no detections), 50.8ms
# image 2/303 /content/drive/MyDrive/wadidaw/negatif/25018301B-381/IMG_6009.JPG: 512x640 (no detections), 50.5ms
# ...

# %% [markdown]
# ## Neg_25014002B-360

# %%
# !python detect.py --weights /content/drive/MyDrive/wadidaw/Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/negatif/25014002B-360
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/negatif/25014002B-360, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-186-g7f097dd Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/300 /content/drive/MyDrive/wadidaw/negatif/25014002B-360/IMG_7636.JPG: 640x512 (no detections), 29.7ms
# image 2/300 /content/drive/MyDrive/wadidaw/negatif/25014002B-360/IMG_7637.JPG: 640x512 (no detections), 22.4ms
# ...

# %%
# !zip -r /content/Negatif_25014002B-360_Yolov5l6.zip /content/yolov5/runs/detect/exp

from google.colab import files
files.download("/content/Negatif_25014002B-360_Yolov5l6.zip")
# Out:
#   adding: content/yolov5/runs/detect/exp/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp/IMG_5256.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp/IMG_5257.JPG (deflated 2%)

# %% [markdown]
# ## Neg_25017306B-373

# %%
# !python detect.py --weights /content/drive/MyDrive/wadidaw/Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/negatif/25017306B-373
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/negatif/25017306B-373, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-186-g7f097dd Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/302 /content/drive/MyDrive/wadidaw/negatif/25017306B-373/IMG_5522.JPG: 640x512 7 AFBs, 29.2ms
# image 2/302 /content/drive/MyDrive/wadidaw/negatif/25017306B-373/IMG_5523.JPG: 640x512 (no detections), 22.3ms
# ...

# %%
# !zip -r /content/Negatif_25017306B-373_Yolov5l6.zip /content/yolov5/runs/detect/exp3

from google.colab import files
files.download("/content/Negatif_25017306B-373_Yolov5l6.zip")
# Out:
#   adding: content/yolov5/runs/detect/exp3/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp3/IMG_7569.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp3/IMG_7615.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp3/IMG_7598.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp3/IMG_6524.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp3/IMG_7404.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp3/IMG_7535.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp3/IMG_7516.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp3/IMG_6526.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp3/IMG_6487.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp3/IMG_7574.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp3/IMG_7575.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp3/IMG_7555.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp3/IMG_6496.JPG (deflated 3%)
# ...

# %%
/content/drive/MyDrive/wadidaw/negatif/25017306B-373

# %% [markdown]
# ## Neg_25022602A-417

# %%
# !python detect.py --weights /content/drive/MyDrive/wadidaw/Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/negatif/25022602A-417
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/negatif/25022602A-417, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-186-g7f097dd Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/300 /content/drive/MyDrive/wadidaw/negatif/25022602A-417/IMG_5711.JPG: 640x512 24 AFBs, 27.6ms
# image 2/300 /content/drive/MyDrive/wadidaw/negatif/25022602A-417/IMG_5712.JPG: 640x512 16 AFBs, 23.9ms
# ...

# %%
# !zip -r /content/negatif_25022602A-417_Yolov5l6.zip /content/yolov5/runs/detect/exp2



from google.colab import files
files.download("/content/negatif_25022602A-417_Yolov5l6.zip")
# Out:
#   adding: content/yolov5/runs/detect/exp2/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6298.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6369.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6270.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6275.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6242.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_5795.JPG (deflated 1%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6281.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6354.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6389.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6255.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6338.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6290.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp2/IMG_6407.JPG (deflated 3%)
# ...

# %% [markdown]
# # Positif

# %% [markdown]
# ## 1+

# %%
# !zip -r /content/Scanty_25001201A-206_Yolov5l6.zip /content/yolov5/runs/detect/exp2

from google.colab import files
files.download("/content/Scanty_25001201A-206_Yolov5l6.zip")

# %%
# 25001001B-204
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P1/25001001B-204
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P1/25001001B-204, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/300 /content/drive/MyDrive/wadidaw/positif/P1/25001001B-204/IMG_5256.JPG: 512x640 34 AFBs, 48.7ms
# image 2/300 /content/drive/MyDrive/wadidaw/positif/P1/25001001B-204/IMG_5257.JPG: 512x640 32 AFBs, 48.4ms
# ...

# %%
# 25005001A-220
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P1/25005001A-220
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P1/25005001A-220, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/300 /content/drive/MyDrive/wadidaw/positif/P1/25005001A-220/IMG_5247.JPG: 512x640 63 AFBs, 48.7ms
# image 2/300 /content/drive/MyDrive/wadidaw/positif/P1/25005001A-220/IMG_5248.JPG: 512x640 25 AFBs, 48.4ms
# ...

# %%
# !zip -r /content/P1_25005001A-220_Yolov5l6.zip /content/yolov5/runs/detect/exp16

from google.colab import files
files.download("/content/P1_25005001A-220_Yolov5l6.zip")
# Out:
#   adding: content/yolov5/runs/detect/exp16/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9626.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9353.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9465.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9379.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9522.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9402.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9445.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9489.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9394.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9438.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9588.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9352.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp16/IMG_9512.JPG (deflated 2%)
# ...

# %%
# 25012101A-331
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P1/25012101A-331
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P1/25012101A-331, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/301 /content/drive/MyDrive/wadidaw/positif/P1/25012101A-331/IMG_5534.JPG: 512x640 43 AFBs, 49.7ms
# image 2/301 /content/drive/MyDrive/wadidaw/positif/P1/25012101A-331/IMG_5535.JPG: 512x640 79 AFBs, 49.4ms
# ...

# %%
# !zip -r /content/P1_25012101A-331_Yolov5l6.zip /content/yolov5/runs/detect/exp17

from google.colab import files
files.download("/content/P1_25012101A-331_Yolov5l6.zip")
# Out:
# updating: content/yolov5/runs/detect/exp17/ (stored 0%)
# updating: content/yolov5/runs/detect/exp17/IMG_8795.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp17/IMG_8785.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp17/IMG_8718.JPG (deflated 3%)
# updating: content/yolov5/runs/detect/exp17/IMG_8636.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp17/IMG_5551.JPG (deflated 1%)
# updating: content/yolov5/runs/detect/exp17/IMG_8646.JPG (deflated 3%)
# updating: content/yolov5/runs/detect/exp17/IMG_8719.JPG (deflated 3%)
# updating: content/yolov5/runs/detect/exp17/IMG_8788.JPG (deflated 3%)
# updating: content/yolov5/runs/detect/exp17/IMG_8807.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp17/IMG_8798.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp17/IMG_8790.JPG (deflated 3%)
# updating: content/yolov5/runs/detect/exp17/IMG_8694.JPG (deflated 3%)
# updating: content/yolov5/runs/detect/exp17/IMG_8828.JPG (deflated 2%)
# ...

# %%
# 25012501A-342
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P1/25012501A-342
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P1/25012501A-342, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/304 /content/drive/MyDrive/wadidaw/positif/P1/25012501A-342/IMG_3533.JPG: 512x640 3 AFBs, 49.8ms
# image 2/304 /content/drive/MyDrive/wadidaw/positif/P1/25012501A-342/IMG_3536.JPG: 512x640 13 AFBs, 49.5ms
# ...

# %%
# !zip -r /content/P1_25012501A-342_Yolov5l6.zip /content/yolov5/runs/detect/exp18

from google.colab import files
files.download("/content/P1_25012501A-342_Yolov5l6.zip")
# Out:
#   adding: content/yolov5/runs/detect/exp18/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3814.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3843.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3624.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3745.JPG (deflated 1%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3736.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3683.JPG (deflated 1%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3782.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3853.JPG (deflated 1%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3539.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3842.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3690.JPG (deflated 1%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3772.JPG (deflated 1%)
#   adding: content/yolov5/runs/detect/exp18/IMG_3591.JPG (deflated 2%)
# ...

# %%
# 25013501A-344
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P1/25013501A-344
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P1/25013501A-344, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/305 /content/drive/MyDrive/wadidaw/positif/P1/25013501A-344/IMG_9041.JPG: 512x640 12 AFBs, 49.7ms
# image 2/305 /content/drive/MyDrive/wadidaw/positif/P1/25013501A-344/IMG_9042.JPG: 512x640 11 AFBs, 49.4ms
# ...

# %%
# !zip -r /content/P1_25013501A-344_Yolov5l6.zip /content/yolov5/runs/detect/exp19

from google.colab import files
files.download("/content/P1_25013501A-344_Yolov5l6.zip")
# Out:
#   adding: content/yolov5/runs/detect/exp19/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9343.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9124.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9337.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9190.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9246.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9252.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9120.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9310.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9158.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9195.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9232.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9056.JPG (deflated 3%)
#   adding: content/yolov5/runs/detect/exp19/IMG_9320.JPG (deflated 3%)
# ...

# %%
# 25023301A-420
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P1/25023301A-420
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P1/25023301A-420, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/301 /content/drive/MyDrive/wadidaw/positif/P1/25023301A-420/IMG_5597.JPG: 512x640 28 AFBs, 50.8ms
# image 2/301 /content/drive/MyDrive/wadidaw/positif/P1/25023301A-420/IMG_5598.JPG: 512x640 15 AFBs, 50.5ms
# ...

# %%
# !zip -r /content/P1_25023301A-420_Yolov5l6.zip /content/yolov5/runs/detect/exp20

from google.colab import files
files.download("/content/P1_25023301A-420_Yolov5l6.zip")
# Out:
#   adding: content/yolov5/runs/detect/exp20/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8201.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8397.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8136.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8216.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8130.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8175.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8222.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8267.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8133.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8192.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8303.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8158.JPG (deflated 2%)
#   adding: content/yolov5/runs/detect/exp20/IMG_8190.JPG (deflated 2%)
# ...

# %% [markdown]
# ## 2+

# %%
# 25001101B1-205
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P2/25001101B1-205
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P2/25001101B1-205, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/109 /content/drive/MyDrive/wadidaw/positif/P2/25001101B1-205/IMG_4444.JPG: 512x640 54 AFBs, 48.7ms
# image 2/109 /content/drive/MyDrive/wadidaw/positif/P2/25001101B1-205/IMG_4445.JPG: 512x640 40 AFBs, 50.5ms
# ...

# %%
# !zip -r /content/P1_25023301A-420_Yolov5l6.zip /content/yolov5/runs/detect/exp23

from google.colab import files
files.download("/content/P1_25023301A-420_Yolov5l6.zip")

# %%
# 25001101B2-205
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P2/25001101B2-205
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P2/25001101B2-205, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/106 /content/drive/MyDrive/wadidaw/positif/P2/25001101B2-205/IMG_2435.JPG: 512x640 29 AFBs, 50.8ms
# image 2/106 /content/drive/MyDrive/wadidaw/positif/P2/25001101B2-205/IMG_2436.JPG: 512x640 57 AFBs, 61.8ms
# ...

# %%
# 25008101B-205
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P2/25008101B-205
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P2/25008101B-205, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/101 /content/drive/MyDrive/wadidaw/positif/P2/25008101B-205/IMG_5359.JPG: 512x640 52 AFBs, 50.9ms
# image 2/101 /content/drive/MyDrive/wadidaw/positif/P2/25008101B-205/IMG_5360.JPG: 512x640 73 AFBs, 50.7ms
# ...

# %%
# 25017301A-371
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P2/25017301A-371
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/positif/P2/25017301A-371, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/110 /content/drive/MyDrive/wadidaw/positif/P2/25017301A-371/IMG_5573.JPG: 512x640 50 AFBs, 50.8ms
# image 2/110 /content/drive/MyDrive/wadidaw/positif/P2/25017301A-371/IMG_5574.JPG: 512x640 117 AFBs, 50.5ms
# ...

# %% [markdown]
# ## 3+

# %%
# 25000901A1-203
# !python detect.py --wcontent/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P3/25000901A1-203

# %%
# 25000901A1-203
# !python detect.py --wcontent/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P3/25000901A1-203

# %%
# 25000901A1-203
# !python detect.py --wcontent/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P3/25000901A1-203

# %%
# 25000901A1-203
# !python detect.py --wcontent/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P3/25000901A1-203

# %%
# 25000901A1-203
# !python detect.py --wcontent/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/positif/P3/25000901A1-203

# %% [markdown]
# # Scanty

# %%
#25001201A-206
# !python detect.py --weights /content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt --img 640 --conf 0.1 --source /content/drive/MyDrive/wadidaw/scanty/25001201A-206
# Out:
# detect: weights=['/content/drive/MyDrive/wadidaw/_Model/Model_yolov5l6_640_32_3200/best.pt'], source=/content/drive/MyDrive/wadidaw/scanty/25001201A-206, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76118664 parameters, 0 gradients, 109.9 GFLOPs
# image 1/307 /content/drive/MyDrive/wadidaw/scanty/25001201A-206/IMG_3190.JPG: 512x640 23 AFBs, 50.8ms
# image 2/307 /content/drive/MyDrive/wadidaw/scanty/25001201A-206/IMG_3191.JPG: 512x640 23 AFBs, 50.5ms
# ...

# %% [markdown]
# #Zipping and ETC

# %%
# !zip -r /content/Scanty_25001201A-206_Yolov5l6.zip /content/yolov5/runs/detect/exp2

from google.colab import files
files.download("/content/Scanty_25001201A-206_Yolov5l6.zip")
# Out:
# updating: content/yolov5/runs/detect/exp2/ (stored 0%)
# updating: content/yolov5/runs/detect/exp2/IMG_3380.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3347.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3331.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3436.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3514.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3515.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3513.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3301.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3343.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3252.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3209.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3333.JPG (deflated 2%)
# updating: content/yolov5/runs/detect/exp2/IMG_3481.JPG (deflated 2%)
# ...

# %%
#export your model's weights for future use
from google.colab import files
files.download('./runs/train/exp8/weights/best.pt')

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.JPG'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
from skimage import data, io
import matplotlib.pyplot as plt 
name = 'IMG_1995.JPG'
Ori=io.imread('/content/Untitled_Folder/IMG_1995.JPG') 
Result =io.imread('/content/yolov5/runs/detect/exp4/IMG_1995.JPG') 
print(' ')
print("\033[1;30;43mData ID : ",name)
print('-----------------------')
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1), plt.title(name), plt.imshow(Ori), plt.axis('off')
plt.subplot(1, 2, 2), plt.title('Prediction'),plt.imshow(Result), plt.axis('off')
